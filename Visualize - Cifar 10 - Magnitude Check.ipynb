# %%
import augmentation, torch, torchvision
import matplotlib.pyplot as plt

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %%
dataset = torchvision.datasets.CIFAR10('../../../../data/OCR/Jason/cifar10/', train=False, download=False)

# %%
ex1, ex2, ex3, ex4 = dataset[2], dataset[25], dataset[28], dataset[42]

# %%
M = 10

color_range = torch.arange(0, 0.9+1e-8, (0.9-0)/M).tolist()
rotate_range = torch.arange(0, 30+1e-8, (30-0)/M).tolist()
shear_range = torch.arange(0, 0.3+1e-8, (0.3-0)/M).tolist()
translate_range = torch.arange(0, 10+1e-8, (10-0)/M).tolist()


Mag = {'Brightness' : color_range, 'Color' : color_range, 'Contrast' : color_range, 
       'Posterize' : torch.arange(4, 8+1e-8, (8-4)/M).tolist()[::-1], 'Sharpness' : color_range, 
       'Solarize' : torch.arange(0, 256+1e-8, (256-0)/M).tolist()[::-1], 
       
       'Cutout' : torch.arange(0, 32*0.15+1e-8, (32*0.15-0)/M),
       
       'Rotate' : rotate_range, 'ShearX' : shear_range, 'ShearY' : shear_range,
       'TranslateX' : translate_range, 'TranslateY' : translate_range}


Fun = {'Brightness' : augmentation.Brightness, 'Color' : augmentation.Color, 'Contrast' : augmentation.Contrast,  
       'Posterize' : augmentation.Posterize, 'Sharpness' : augmentation.Sharpness, 'Solarize' : augmentation.Solarize, 
       
       'Cutout' : augmentation.Cutout,
         
       'Rotate' : augmentation.Rotate, 'ShearX' : augmentation.ShearX, 'ShearY' : augmentation.ShearY, 
       'TranslateX' : augmentation.TranslateX, 'TranslateY' : augmentation.TranslateY}

# %%
aug_list, title_list = [], []
M = [4, 10]

for f in Fun:
    if f in ['Cutout', 'Posterize', 'Solarize']: aug_list.append([Fun[f](1, Mag[f][M[0]]), Fun[f](1, Mag[f][M[1]])])
    else: aug_list.append([Fun[f](1, Mag[f][M[0]], minus=False), Fun[f](1, Mag[f][M[1]], minus=False)])
    title_list.append(['Function : {}, Magnitude : {}'.format(f, M[0]), 'Function : {}, Magnitude : {}'.format(f, M[1])])

# %%
for a, t in zip(aug_list, title_list):
    print(a)
    print(t)
    print()
# Out:
# [Brightness(p=1, magnitude=0.36000001430511475), Brightness(p=1, magnitude=0.8999999761581421)]
# ['Function : Brightness, Magnitude : 4', 'Function : Brightness, Magnitude : 10']
#
# [Color(p=1, magnitude=0.36000001430511475), Color(p=1, magnitude=0.8999999761581421)]
# ['Function : Color, Magnitude : 4', 'Function : Color, Magnitude : 10']
#
# [Contrast(p=1, magnitude=0.36000001430511475), Contrast(p=1, magnitude=0.8999999761581421)]
# ['Function : Contrast, Magnitude : 4', 'Function : Contrast, Magnitude : 10']
#
# [Posterize(p=1, bits=6), Posterize(p=1, bits=4)]
# ['Function : Posterize, Magnitude : 4', 'Function : Posterize, Magnitude : 10']
#
# [Sharpness(p=1, magnitude=0.36000001430511475), Sharpness(p=1, magnitude=0.8999999761581421)]
# ['Function : Sharpness, Magnitude : 4', 'Function : Sharpness, Magnitude : 10']
#
# [Solarize(p=1, threshold=153), Solarize(p=1, threshold=0)]
# ['Function : Solarize, Magnitude : 4', 'Function : Solarize, Magnitude : 10']
#
# [Cutout(p=1, pad_size=2), Cutout(p=1, pad_size=5)]
# ['Function : Cutout, Magnitude : 4', 'Function : Cutout, Magnitude : 10']
#
# [Rotate(p=1, degrees=12.0), Rotate(p=1, degrees=30.0)]
# ['Function : Rotate, Magnitude : 4', 'Function : Rotate, Magnitude : 10']
#
# [ShearX(p=1, level=0.11999999731779099), ShearX(p=1, level=0.30000001192092896)]
# ['Function : ShearX, Magnitude : 4', 'Function : ShearX, Magnitude : 10']
#
# [ShearY(p=1, level=0.11999999731779099), ShearY(p=1, level=0.30000001192092896)]
# ['Function : ShearY, Magnitude : 4', 'Function : ShearY, Magnitude : 10']
#
# [TranslateX(p=1, pixels=4), TranslateX(p=1, pixels=10)]
# ['Function : TranslateX, Magnitude : 4', 'Function : TranslateX, Magnitude : 10']
#
# [TranslateY(p=1, pixels=4), TranslateY(p=1, pixels=10)]
# ['Function : TranslateY, Magnitude : 4', 'Function : TranslateY, Magnitude : 10']

# %%
plt.figure(figsize=(15, 70))
plt.rcParams['axes.titlesize'] = 12
plt.axis('off')

for i in range(len(aug_list)):
    plt.subplot(12, 3, 3*i+1)
    image, label = ex1
    img = plt.imshow(image); img.axes.get_xaxis().set_visible(False); img.axes.get_yaxis().set_visible(False)
    plt.gca().set_title('GT')
    
    for j in range(len(aug_list[i])):
        plt.subplot(12, 3, 3*i + j + 2)
        aug_image = aug_list[i][j](image)
        aug_image = plt.imshow(aug_image)
        aug_image.axes.get_xaxis().set_visible(False); aug_image.axes.get_yaxis().set_visible(False)
        plt.gca().set_title(title_list[i][j])

# %%
plt.figure(figsize=(15, 70))
plt.rcParams['axes.titlesize'] = 12
plt.axis('off')

for i in range(len(aug_list)):
    plt.subplot(12, 3, 3*i+1)
    image, label = ex2
    img = plt.imshow(image); img.axes.get_xaxis().set_visible(False); img.axes.get_yaxis().set_visible(False)
    plt.gca().set_title('GT')

    for j in range(len(aug_list[i])):
        plt.subplot(12, 3, 3*i + j + 2)
        aug_image = aug_list[i][j](image)
        aug_image = plt.imshow(aug_image)
        aug_image.axes.get_xaxis().set_visible(False); aug_image.axes.get_yaxis().set_visible(False)
        plt.gca().set_title(title_list[i][j])

# %%
plt.figure(figsize=(15, 70))
plt.rcParams['axes.titlesize'] = 12
plt.axis('off')

for i in range(len(aug_list)):
    plt.subplot(12, 3, 3*i+1)
    image, label = ex3
    img = plt.imshow(image); img.axes.get_xaxis().set_visible(False); img.axes.get_yaxis().set_visible(False)
    plt.gca().set_title('GT')

    for j in range(len(aug_list[i])):
        plt.subplot(12, 3, 3*i + j + 2)
        aug_image = aug_list[i][j](image)
        aug_image = plt.imshow(aug_image)
        aug_image.axes.get_xaxis().set_visible(False); aug_image.axes.get_yaxis().set_visible(False)
        plt.gca().set_title(title_list[i][j])

# %%
plt.figure(figsize=(15, 70))
plt.rcParams['axes.titlesize'] = 12
plt.axis('off')

for i in range(len(aug_list)):
    plt.subplot(12, 3, 3*i+1)
    image, label = ex4
    img = plt.imshow(image); img.axes.get_xaxis().set_visible(False); img.axes.get_yaxis().set_visible(False)
    plt.gca().set_title('GT')
    
    for j in range(len(aug_list[i])):
        plt.subplot(12, 3, 3*i + j + 2)
        aug_image = aug_list[i][j](image)
        aug_image = plt.imshow(aug_image)
        aug_image.axes.get_xaxis().set_visible(False); aug_image.axes.get_yaxis().set_visible(False)
        plt.gca().set_title(title_list[i][j])
