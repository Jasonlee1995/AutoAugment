# %% [markdown]
# # AutoAugment on Wide ResNet 28 10 with ImageNet policy
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ## 1.1. Import

# %%
import augmentation, policy, train
import torch, torchvision
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
batch_size = 128
cifar_dir = '../../../../data/OCR/Jason/cifar10/'

policy_type = 'imagenet'

# %%
pre_train_transform = [transforms.RandomCrop(32, padding=4), transforms.RandomHorizontalFlip()]
post_train_transform = [augmentation.Cutout(1, 8), transforms.ToTensor(), 
                        transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])]

train_transform = policy.Policy(policy_type, pre_train_transform, post_train_transform)

test_transform = transforms.Compose([transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

train_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=True, download=False, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=False)

test_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=False, download=False, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=False)

# %% [markdown]
# # 3. Train Model

# %%
depth = 28
widen_factor = 10
dropout_rate = 0.3
num_classes = 10

gpu_id = 6
print_freq = 60
epoch_print = 10

save = False
epochs = 201

lr = 0.1
momentum = 0.9
weight_decay = 0.0005
nesterov = True
milestones = [60, 120, 160]

# %%
WRN_28_10 = train.Wide_ResNet(depth, widen_factor, dropout_rate, num_classes, gpu_id, print_freq, epoch_print)

# %%
WRN_28_10.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay, nesterov, milestones)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 2.0845, Test Loss : 2.2994, Train Acc : 19.5312, Test Acc : 20.3900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 2.0124, Test Loss : 2.0011, Train Acc : 21.8750, Test Acc : 25.4100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 1.9520, Test Loss : 1.9251, Train Acc : 29.6875, Test Acc : 30.3400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 1.8287, Test Loss : 1.7087, Train Acc : 34.3750, Test Acc : 36.9300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7638, Test Loss : 1.6267, Train Acc : 33.5938, Test Acc : 41.3500
# Iteration : 360 - Train Loss : 1.7596, Test Loss : 1.8157, Train Acc : 32.8125, Test Acc : 40.8900
# Epoch 11 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.9630, Test Loss : 0.7958, Train Acc : 67.1875, Test Acc : 74.4800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.8817, Test Loss : 0.6027, Train Acc : 64.0625, Test Acc : 79.2800
# Iteration : 180 - Train Loss : 0.9289, Test Loss : 0.6590, Train Acc : 68.7500, Test Acc : 77.0600
# Iteration : 240 - Train Loss : 0.8025, Test Loss : 0.7588, Train Acc : 70.3125, Test Acc : 75.4500
# Iteration : 300 - Train Loss : 0.8482, Test Loss : 0.6887, Train Acc : 68.7500, Test Acc : 77.3700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 1.0923, Test Loss : 0.5850, Train Acc : 67.9688, Test Acc : 79.8600
# Epoch 21 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.9315, Test Loss : 0.4709, Train Acc : 71.0938, Test Acc : 83.5500
# Iteration : 120 - Train Loss : 0.6419, Test Loss : 0.4752, Train Acc : 77.3438, Test Acc : 83.5100
# Iteration : 180 - Train Loss : 0.9453, Test Loss : 0.7623, Train Acc : 67.1875, Test Acc : 76.5600
# Iteration : 240 - Train Loss : 0.7829, Test Loss : 0.6111, Train Acc : 71.8750, Test Acc : 79.0300
# Iteration : 300 - Train Loss : 0.7172, Test Loss : 0.5254, Train Acc : 77.3438, Test Acc : 82.8500
# Iteration : 360 - Train Loss : 0.7436, Test Loss : 0.5139, Train Acc : 71.8750, Test Acc : 82.7400
# Epoch 31 Started...
# Iteration : 60 - Train Loss : 0.8326, Test Loss : 0.7807, Train Acc : 71.0938, Test Acc : 75.5800
# Iteration : 120 - Train Loss : 0.7943, Test Loss : 0.6163, Train Acc : 72.6562, Test Acc : 80.2700
# Iteration : 180 - Train Loss : 0.7194, Test Loss : 0.4857, Train Acc : 73.4375, Test Acc : 83.4000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.7279, Test Loss : 0.4417, Train Acc : 69.5312, Test Acc : 85.2700
# Iteration : 300 - Train Loss : 0.8343, Test Loss : 0.5113, Train Acc : 70.3125, Test Acc : 82.0600
# Iteration : 360 - Train Loss : 0.9133, Test Loss : 0.5147, Train Acc : 69.5312, Test Acc : 82.7600
# Epoch 41 Started...
# Iteration : 60 - Train Loss : 0.8887, Test Loss : 0.4598, Train Acc : 70.3125, Test Acc : 84.0800
# Iteration : 120 - Train Loss : 0.7942, Test Loss : 0.5027, Train Acc : 72.6562, Test Acc : 83.5500
# Iteration : 180 - Train Loss : 0.8229, Test Loss : 0.4519, Train Acc : 71.0938, Test Acc : 84.8400
# Iteration : 240 - Train Loss : 0.8321, Test Loss : 0.4751, Train Acc : 73.4375, Test Acc : 83.4800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.6515, Test Loss : 0.4262, Train Acc : 76.5625, Test Acc : 85.5400
# Iteration : 360 - Train Loss : 0.7453, Test Loss : 0.4278, Train Acc : 77.3438, Test Acc : 85.2000
# Epoch 51 Started...
# Iteration : 60 - Train Loss : 0.6743, Test Loss : 0.4831, Train Acc : 78.9062, Test Acc : 83.7100
# Iteration : 120 - Train Loss : 0.7391, Test Loss : 0.5535, Train Acc : 78.1250, Test Acc : 80.5600
# Iteration : 180 - Train Loss : 0.6067, Test Loss : 0.6104, Train Acc : 79.6875, Test Acc : 80.0500
# Iteration : 240 - Train Loss : 0.7270, Test Loss : 0.4928, Train Acc : 72.6562, Test Acc : 83.8300
# Iteration : 300 - Train Loss : 0.6273, Test Loss : 0.5964, Train Acc : 78.1250, Test Acc : 80.1400
# Iteration : 360 - Train Loss : 0.9642, Test Loss : 0.6576, Train Acc : 64.8438, Test Acc : 78.7300
# Epoch 61 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.6896, Test Loss : 0.2729, Train Acc : 78.9062, Test Acc : 90.6200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.6259, Test Loss : 0.2514, Train Acc : 82.0312, Test Acc : 91.3200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.6033, Test Loss : 0.2461, Train Acc : 79.6875, Test Acc : 91.6700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.4328, Test Loss : 0.2430, Train Acc : 83.5938, Test Acc : 91.7600
# Iteration : 300 - Train Loss : 0.4027, Test Loss : 0.2419, Train Acc : 84.3750, Test Acc : 91.5800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.4839, Test Loss : 0.2376, Train Acc : 83.5938, Test Acc : 91.9500
# Epoch 71 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.4951, Test Loss : 0.2194, Train Acc : 81.2500, Test Acc : 92.5200
# Iteration : 120 - Train Loss : 0.4185, Test Loss : 0.2322, Train Acc : 84.3750, Test Acc : 92.2600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.3755, Test Loss : 0.2117, Train Acc : 85.9375, Test Acc : 92.6800
# Iteration : 240 - Train Loss : 0.3709, Test Loss : 0.2124, Train Acc : 88.2812, Test Acc : 92.6800
# Iteration : 300 - Train Loss : 0.3367, Test Loss : 0.2264, Train Acc : 88.2812, Test Acc : 92.3200
# Iteration : 360 - Train Loss : 0.4751, Test Loss : 0.2138, Train Acc : 85.1562, Test Acc : 92.5700
# Epoch 81 Started...
# Iteration : 60 - Train Loss : 0.4183, Test Loss : 0.2287, Train Acc : 85.9375, Test Acc : 91.9500
# Iteration : 120 - Train Loss : 0.4377, Test Loss : 0.2186, Train Acc : 85.9375, Test Acc : 92.5300
# Iteration : 180 - Train Loss : 0.3275, Test Loss : 0.2412, Train Acc : 87.5000, Test Acc : 91.6800
# Iteration : 240 - Train Loss : 0.4978, Test Loss : 0.2435, Train Acc : 83.5938, Test Acc : 92.0000
# Iteration : 300 - Train Loss : 0.2968, Test Loss : 0.2419, Train Acc : 91.4062, Test Acc : 92.2400
# Iteration : 360 - Train Loss : 0.4406, Test Loss : 0.2490, Train Acc : 81.2500, Test Acc : 91.6100
# Epoch 91 Started...
# Iteration : 60 - Train Loss : 0.3406, Test Loss : 0.2244, Train Acc : 89.0625, Test Acc : 92.5800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.4223, Test Loss : 0.2153, Train Acc : 85.9375, Test Acc : 92.7200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.4482, Test Loss : 0.2127, Train Acc : 85.1562, Test Acc : 92.8200
# Iteration : 240 - Train Loss : 0.5110, Test Loss : 0.2160, Train Acc : 78.1250, Test Acc : 92.7500
# Iteration : 300 - Train Loss : 0.3552, Test Loss : 0.2205, Train Acc : 91.4062, Test Acc : 92.5600
# Iteration : 360 - Train Loss : 0.3759, Test Loss : 0.2248, Train Acc : 89.0625, Test Acc : 92.4900
# Epoch 101 Started...
# Iteration : 60 - Train Loss : 0.5431, Test Loss : 0.2242, Train Acc : 83.5938, Test Acc : 92.3200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.3172, Test Loss : 0.1979, Train Acc : 90.6250, Test Acc : 93.2000
# Iteration : 180 - Train Loss : 0.3556, Test Loss : 0.2068, Train Acc : 84.3750, Test Acc : 92.8000
# Iteration : 240 - Train Loss : 0.4802, Test Loss : 0.2534, Train Acc : 86.7188, Test Acc : 91.2000
# Iteration : 300 - Train Loss : 0.3771, Test Loss : 0.2086, Train Acc : 86.7188, Test Acc : 92.9700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.4748, Test Loss : 0.1977, Train Acc : 83.5938, Test Acc : 93.3400
# Epoch 111 Started...
# Iteration : 60 - Train Loss : 0.4296, Test Loss : 0.2132, Train Acc : 84.3750, Test Acc : 93.0000
# Iteration : 120 - Train Loss : 0.4879, Test Loss : 0.2125, Train Acc : 82.8125, Test Acc : 92.7500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.3549, Test Loss : 0.1910, Train Acc : 85.9375, Test Acc : 93.5200
# Iteration : 240 - Train Loss : 0.5077, Test Loss : 0.2137, Train Acc : 82.0312, Test Acc : 92.9200
# Iteration : 300 - Train Loss : 0.4522, Test Loss : 0.2209, Train Acc : 83.5938, Test Acc : 92.7100
# Iteration : 360 - Train Loss : 0.4005, Test Loss : 0.2256, Train Acc : 86.7188, Test Acc : 92.5100
# Epoch 121 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.3842, Test Loss : 0.1482, Train Acc : 88.2812, Test Acc : 94.9900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.3061, Test Loss : 0.1484, Train Acc : 88.2812, Test Acc : 95.1000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.2504, Test Loss : 0.1404, Train Acc : 92.1875, Test Acc : 95.2300
# Iteration : 240 - Train Loss : 0.2854, Test Loss : 0.1412, Train Acc : 91.4062, Test Acc : 95.2300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.2811, Test Loss : 0.1335, Train Acc : 90.6250, Test Acc : 95.3500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.3173, Test Loss : 0.1356, Train Acc : 90.6250, Test Acc : 95.4000
# Epoch 131 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.1912, Test Loss : 0.1319, Train Acc : 91.4062, Test Acc : 95.7800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.2424, Test Loss : 0.1221, Train Acc : 90.6250, Test Acc : 95.9700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.2968, Test Loss : 0.1246, Train Acc : 88.2812, Test Acc : 96.0500
# Iteration : 240 - Train Loss : 0.1893, Test Loss : 0.1259, Train Acc : 93.7500, Test Acc : 95.9200
# Iteration : 300 - Train Loss : 0.2030, Test Loss : 0.1255, Train Acc : 92.9688, Test Acc : 96.0100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.2160, Test Loss : 0.1200, Train Acc : 93.7500, Test Acc : 96.1400
# Epoch 141 Started...
# Iteration : 60 - Train Loss : 0.2427, Test Loss : 0.1248, Train Acc : 93.7500, Test Acc : 96.0100
# Iteration : 120 - Train Loss : 0.2304, Test Loss : 0.1209, Train Acc : 91.4062, Test Acc : 96.0100
# Iteration : 180 - Train Loss : 0.1285, Test Loss : 0.1210, Train Acc : 97.6562, Test Acc : 96.0600
# Iteration : 240 - Train Loss : 0.2349, Test Loss : 0.1229, Train Acc : 94.5312, Test Acc : 96.0500
# Iteration : 300 - Train Loss : 0.1607, Test Loss : 0.1308, Train Acc : 93.7500, Test Acc : 95.9300
# Iteration : 360 - Train Loss : 0.1580, Test Loss : 0.1241, Train Acc : 93.7500, Test Acc : 95.9500
# Epoch 151 Started...
# Iteration : 60 - Train Loss : 0.2116, Test Loss : 0.1348, Train Acc : 92.9688, Test Acc : 95.8800
# Iteration : 120 - Train Loss : 0.2365, Test Loss : 0.1337, Train Acc : 91.4062, Test Acc : 95.8400
# Iteration : 180 - Train Loss : 0.1981, Test Loss : 0.1277, Train Acc : 92.1875, Test Acc : 96.0900
# Iteration : 240 - Train Loss : 0.2408, Test Loss : 0.1405, Train Acc : 91.4062, Test Acc : 95.6800
# Iteration : 300 - Train Loss : 0.2004, Test Loss : 0.1305, Train Acc : 95.3125, Test Acc : 95.9700
# Iteration : 360 - Train Loss : 0.2721, Test Loss : 0.1245, Train Acc : 92.9688, Test Acc : 96.0800
# Epoch 161 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.1554, Test Loss : 0.1200, Train Acc : 96.8750, Test Acc : 96.2900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.2747, Test Loss : 0.1156, Train Acc : 89.8438, Test Acc : 96.4800
# Iteration : 180 - Train Loss : 0.1451, Test Loss : 0.1164, Train Acc : 94.5312, Test Acc : 96.3200
# Iteration : 240 - Train Loss : 0.1822, Test Loss : 0.1158, Train Acc : 94.5312, Test Acc : 96.2800
# Iteration : 300 - Train Loss : 0.2106, Test Loss : 0.1149, Train Acc : 92.1875, Test Acc : 96.3900
# Iteration : 360 - Train Loss : 0.2256, Test Loss : 0.1150, Train Acc : 92.1875, Test Acc : 96.3700
# Epoch 171 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.1540, Test Loss : 0.1069, Train Acc : 91.4062, Test Acc : 96.6500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.1806, Test Loss : 0.1057, Train Acc : 93.7500, Test Acc : 96.7800
# Iteration : 180 - Train Loss : 0.0805, Test Loss : 0.1085, Train Acc : 97.6562, Test Acc : 96.7500
# Iteration : 240 - Train Loss : 0.0907, Test Loss : 0.1074, Train Acc : 97.6562, Test Acc : 96.6900
# Iteration : 300 - Train Loss : 0.1002, Test Loss : 0.1084, Train Acc : 96.0938, Test Acc : 96.6600
# Iteration : 360 - Train Loss : 0.1397, Test Loss : 0.1058, Train Acc : 94.5312, Test Acc : 96.7700
# Epoch 181 Started...
# Iteration : 60 - Train Loss : 0.1864, Test Loss : 0.1086, Train Acc : 95.3125, Test Acc : 96.7200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.1526, Test Loss : 0.1077, Train Acc : 92.9688, Test Acc : 96.8300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.1356, Test Loss : 0.1094, Train Acc : 94.5312, Test Acc : 96.8700
# Iteration : 240 - Train Loss : 0.1264, Test Loss : 0.1078, Train Acc : 96.0938, Test Acc : 96.7400
# Iteration : 300 - Train Loss : 0.1834, Test Loss : 0.1078, Train Acc : 92.1875, Test Acc : 96.8200
# Iteration : 360 - Train Loss : 0.1693, Test Loss : 0.1082, Train Acc : 93.7500, Test Acc : 96.7100
# Epoch 191 Started...
# Iteration : 60 - Train Loss : 0.0642, Test Loss : 0.1064, Train Acc : 97.6562, Test Acc : 96.7400
# Iteration : 120 - Train Loss : 0.1387, Test Loss : 0.1063, Train Acc : 96.0938, Test Acc : 96.7100
# Iteration : 180 - Train Loss : 0.0861, Test Loss : 0.1079, Train Acc : 96.0938, Test Acc : 96.8300
# Iteration : 240 - Train Loss : 0.1283, Test Loss : 0.1087, Train Acc : 95.3125, Test Acc : 96.7000
# Iteration : 300 - Train Loss : 0.1214, Test Loss : 0.1070, Train Acc : 95.3125, Test Acc : 96.8300
# Iteration : 360 - Train Loss : 0.1145, Test Loss : 0.1060, Train Acc : 96.0938, Test Acc : 96.8400
# Epoch 201 Started...
# Iteration : 60 - Train Loss : 0.0873, Test Loss : 0.1076, Train Acc : 96.0938, Test Acc : 96.8100
# Iteration : 120 - Train Loss : 0.1727, Test Loss : 0.1059, Train Acc : 95.3125, Test Acc : 96.8700
# Iteration : 180 - Train Loss : 0.1023, Test Loss : 0.1067, Train Acc : 96.0938, Test Acc : 96.8000
# Iteration : 240 - Train Loss : 0.1140, Test Loss : 0.1031, Train Acc : 94.5312, Test Acc : 96.7900
# Iteration : 300 - Train Loss : 0.0988, Test Loss : 0.1076, Train Acc : 96.0938, Test Acc : 96.7300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.1576, Test Loss : 0.1059, Train Acc : 92.9688, Test Acc : 96.9200

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(WRN_28_10.train_losses, label='Train')
test_lossline, = plt.plot(WRN_28_10.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(WRN_28_10.train_acc, label='Train')
test_accline, = plt.plot(WRN_28_10.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')
